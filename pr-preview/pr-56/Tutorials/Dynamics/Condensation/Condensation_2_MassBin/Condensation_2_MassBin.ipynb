# %% [markdown]
# # Condensation Tutorial: Mass Binned
#
# *Work in progress, probably split into multiple notebooks, need to find a model system to test this on*
#
# A particle resolved model is a model that tracks the properties of individual particles or collection of particles (e.g., super droplets). This is in contrast to a bulk model, which tracks the properties of the entire aerosol population. The particle resolved model can be more computationally expensive, but can provide more detailed information about the aerosol population.
#
# To run this type of model we will need to use a speciated distribution representation. This is so that we can track the properties of individual particles.

# %%
import numpy as np
import matplotlib.pyplot as plt

# particula imports
from particula.next import particles
from particula.next.gas.atmosphere_builders import AtmosphereBuilder
from particula.next.gas.vapor_pressure_factories import VaporPressureFactory
from particula.next.gas.species_builders import GasSpeciesBuilder
from particula.next.aerosol import Aerosol
from particula.next.dynamics.particle_process import MassCondensation
from particula.next.dynamics.condensation import CondensationIsothermal

# %% [markdown]
# ## Aerosol Object
#
# First we'll draw from a lognormal distribution to create a set of particles. We'll will then build an aerosol object to represent the aerosol population.

# %%
# Ammonium sulfate and water vapor pressure
molar_mass_ammonium_sulfate = 132.14e-3  # kg/mol
molar_mass_water = 18.015e-3  # kg/mol
parameters_vapor = {
    "vapor_pressure": 1e-20,
}
vapor_pressure_ammonium = VaporPressureFactory().get_strategy(
    "constant", parameters_vapor
)
vapor_pressure_water = VaporPressureFactory().get_strategy(
    "water_buck"
)

water_sat = vapor_pressure_water.saturation_concentration(molar_mass=molar_mass_water, temperature=298.15)
water_concentration = 0.95 * water_sat

glycerol_gas = (
    GasSpeciesBuilder()
    .set_molar_mass(np.array([molar_mass_water, molar_mass_ammonium_sulfate]), "kg/mol")
    .set_vapor_pressure_strategy([vapor_pressure_water, vapor_pressure_ammonium])
    .set_concentration(np.array([water_concentration, 0.0]), "kg/m^3")
    .set_name(["H2O", "NH4HSO4"])
    .set_condensable([True, True])
    .build()
)

atmosphere = (
    AtmosphereBuilder()
    .add_species(glycerol_gas)
    .set_temperature(25, temperature_units="degC")
    .set_pressure(1, pressure_units="atm")
    .build()
)

# %% [markdown]
# ## Sample Distribution
#
# Next we'll sample the distribution to get a set of particles. We'll then build an aerosol object to represent the aerosol population.

# %%
# sample
particles_sample = particles.properties.lognormal_sample_distribution(
    mode=np.array([100, 1000])*1e-9,
    geometric_standard_deviation=np.array([1.3, 1.5]),
    number_of_particles=np.array([1e3, 1e2]),
    number_of_samples=1000,
)

# histogram lognormal
bins_lognormal = np.logspace(-8, -4, 100)
bins, edges = np.histogram(particles_sample, bins=bins_lognormal, density=True)
# plot
fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(edges[:-1], bins, width=np.diff(edges), align="edge")
ax.set_xscale("log")
ax.set_xlabel("Diameter (m)")
ax.set_ylabel("Count")
plt.show()

# %%
# particle radis to mass
density = 1.26e3  # kg/m^3
particle_mass = density * 4 / 3 * np.pi * particles_sample ** 3
mass_speciation = np.array([particle_mass*0, particle_mass]).T  # water, ammonium sulfate
concentration = np.ones_like(particles_sample) * 1e1
densities = np.array([1000, 1.26e3])  # kg/m^3

print(mass_speciation.shape)

activity_strat = (
    particles.ActivityKappaParameterBuilder()
    .set_density(densities)
    .set_kappa(np.array([0.0, 0.61]))
    .set_molar_mass(np.array([molar_mass_water, molar_mass_ammonium_sulfate]))
    .set_water_index(0)
    .build()
)

surface_strat = (
    particles.SurfaceStrategyVolumeBuilder()
    .set_density(densities)
    .set_surface_tension(np.array([0.072, 0.092]))
    .build()
)

paritcle_rep = (
    particles.ParticleMassRepresentationBuilder()
    .set_distribution_strategy(particles.SpeciatedMassMovingBinBuilder().build())
    .set_surface_strategy(surface_strat)
    .set_activity_strategy(activity_strat)
    .set_density(densities)
    .set_charge(0.0)
    .set_mass(mass_speciation)
    .set_concentration(concentration, "1/cm^3")
    .build()
)

aerosol = Aerosol(atmosphere=atmosphere, particles=paritcle_rep)

print(aerosol)
# Out:
# (1000, 2)
# Gas mixture at 298.15 K and 101325.0 Pa consisting of ["['H2O', 'NH4HSO4']"]
# [0]: Particle Representation:
# 	Strategy: SpeciatedMassMovingBin
# 	Activity: ActivityKappaParameter
# 	Surface: SurfaceStrategyVolume
# 	Mass Concentration: 1.147e-05 [kg/m^3]
# 	Number Concentration: 1.000e+10 [#/m^3]

# %% [markdown]
# ## Condensation Process
#
# Using the same iso thermal condensation process as in the bulk model, we'll update the properties of the particles in the aerosol object. In this cas we will change the water saturation ratio to be 80% and simulate the condensation process.

# %%
# define the condensation process
condensation_isothermal = CondensationIsothermal(
    molar_mass=np.array([molar_mass_water, molar_mass_ammonium_sulfate]),  # kg/mol
    diffusion_coefficient=2.0*1e-9,
    accommodation_coefficient=0.1,  #makes things go slower/faster
)
condensation_process = MassCondensation(condensation_strategy=condensation_isothermal)

# define the time array in seconds
time_step = 1000
sub_steps = 100
time_array = np.arange(0, 5, time_step)
total_mass = np.zeros_like(time_array)

# output arrays
aerosol_sim = []

rate = condensation_process.rate(aerosol)
print(f"Inital rate: {rate[:5]}...")

fig, ax = plt.subplots(figsize=(8, 6))
bins, edges = np.histogram(
    aerosol.particles[0].get_radius(), bins=bins_lognormal
)
ax.bar(edges[:-1], bins, width=np.diff(edges), align="edge", label="Initial")

print(aerosol)
# one step
aerosol = condensation_process.execute(aerosol, time_step, sub_steps)
bins, edges = np.histogram(
    aerosol.particles[0].get_radius(), bins=bins_lognormal
)
ax.bar(edges[:-1], bins, width=np.diff(edges), align="edge", label="After 1 step", alpha=0.8)

print(aerosol)
# 10 seconds
aerosol = condensation_process.execute(aerosol, time_step, sub_steps)
bins, edges = np.histogram(
    aerosol.particles[0].get_radius(), bins=bins_lognormal
)
ax.bar(edges[:-1], bins, width=np.diff(edges), align="edge", label="After 2 steps", alpha=0.7)
print(aerosol)

ax.set_xscale("log")
# ax.set_yscale("log")
plt.legend()
ax.set_xlabel("Radius (m)")
ax.set_ylabel("Concentration (1/m^3)")
plt.show()
# Out:
# solute volume fractions: (1000, 1)
# mean water activity: 0.2690655763136162
# Inital rate: [ 4.26647811e-11 -1.10843461e-38  3.18715843e-11 -5.42852797e-39
#   6.45469895e-11]...
# Gas mixture at 298.15 K and 101325.0 Pa consisting of ["['H2O', 'NH4HSO4']"]
# [0]: Particle Representation:
# 	Strategy: SpeciatedMassMovingBin
# 	Activity: ActivityKappaParameter
# 	Surface: SurfaceStrategyVolume
# 	Mass Concentration: 1.147e-05 [kg/m^3]
# 	Number Concentration: 1.000e+10 [#/m^3]
# Saturation ratio: [0.95 0.  ]
# solute volume fractions: (1000, 1)
# mean water activity: 0.2690655763136162
# faction added : [-0.00014566         inf]
# Saturation ratio: [9.49861626e-01 4.84340453e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.08856834861552698
# faction added : [-2.46293207e-04  3.50415225e-01]
# Saturation ratio: [9.49627681e-01 6.54060722e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.30326137260429603
# faction added : [-0.00040753  0.12832614]
# Saturation ratio: [9.49240679e-01 7.37993812e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.6055935772265191
# faction added : [-0.00055749  0.06313669]
# Saturation ratio: [9.48711483e-01 7.84588302e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.7342693374523986
# faction added : [-0.00064504  0.03729144]
# Saturation ratio: [9.48099526e-01 8.13846728e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.793037189415732
# faction added : [-0.00068719  0.02522504]
# Saturation ratio: [9.47448004e-01 8.34376045e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8263112435832071
# faction added : [-0.00070767  0.01866046]
# Saturation ratio: [9.46777528e-01 8.49945884e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8478063484713082
# faction added : [-0.00071882  0.01462362]
# Saturation ratio: [9.46096962e-01 8.62375168e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8628877380406457
# faction added : [-0.00072605  0.01190578]
# Saturation ratio: [9.45410044e-01 8.72642420e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.874073165297595
# faction added : [-0.00073166  0.00994994]
# Saturation ratio: [9.44718329e-01 8.81325161e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8827028542924864
# faction added : [-0.00073661  0.00847053]
# Saturation ratio: [9.44022445e-01 8.88790455e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.889557951715775
# faction added : [-0.00074131  0.00730801]
# Saturation ratio: [9.43322633e-01 8.95285740e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8951258113658951
# faction added : [-0.00074592  0.00636684]
# Saturation ratio: [9.42618989e-01 9.00985880e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8997269957522342
# faction added : [-0.00075049  0.00558655]
# Saturation ratio: [9.41911566e-01 9.06019279e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.903581449082017
# C:\GitHub\particula\particula\next\gas\species.py:277: RuntimeWarning: divide by zero encountered in divide
#   print(f"faction added : {added_concentration/self.concentration}")
# faction added : [-0.000755    0.00492704]
# Saturation ratio: [9.41200421e-01 9.10483270e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9068453718442597
# faction added : [-0.00075945  0.00436069]
# Saturation ratio: [9.40485628e-01 9.14453602e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9096329216117566
# faction added : [-0.0007638   0.00386785]
# Saturation ratio: [9.39767287e-01 9.17990569e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.912029574762714
# faction added : [-0.00076803  0.00343415]
# Saturation ratio: [9.39045521e-01 9.21143090e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9141006729757184
# faction added : [-0.00077211  0.00304884]
# Saturation ratio: [9.38320472e-01 9.23951512e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9158970704703361
# faction added : [-0.00077604  0.0027037 ]
# Saturation ratio: [9.37592299e-01 9.26449597e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9174589718478041
# faction added : [-0.00077979  0.00239231]
# Saturation ratio: [9.36861172e-01 9.28665956e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9188186050298227
# faction added : [-0.00078336  0.00210963]
# Saturation ratio: [9.36127271e-01 9.30625101e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9200021235281808
# faction added : [-0.00078674  0.0018516 ]
# Saturation ratio: [9.35390780e-01 9.32348245e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9210309864563745
# faction added : [-0.00078993  0.00161491]
# Saturation ratio: [9.34651886e-01 9.33853902e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9219229769761976
# faction added : [-0.00079292  0.00139686]
# Saturation ratio: [9.33910780e-01 9.35158366e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9226929655917425
# faction added : [-0.00079572  0.00119521]
# Saturation ratio: [9.33167648e-01 9.36276072e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9233534902542073
# faction added : [-0.00079833  0.00100806]
# Saturation ratio: [9.32422676e-01 9.37219895e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9239152028752918
# faction added : [-0.00080074  0.00083383]
# Saturation ratio: [9.31676048e-01 9.38001381e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9243872170249378
# faction added : [-0.00080297  0.00067118]
# Saturation ratio: [9.30927943e-01 9.38630946e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9247773815812742
# faction added : [-0.00080501  0.00051892]
# Saturation ratio: [9.30178535e-01 9.39118023e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.925092498227133
# faction added : [-0.00080688  0.00037607]
# Saturation ratio: [9.29427994e-01 9.39471201e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9253384958924263
# faction added : [-0.00080857  0.00024176]
# Saturation ratio: [9.28676484e-01 9.39698327e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.
-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9153854604553738
# faction added : [-0.00080541 -0.00180119]
# Saturation ratio: [9.06271627e-01 9.10912556e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9148344162990224
# faction added : [-0.00080423 -0.00183457]
# Saturation ratio: [9.05542777e-01 9.09241423e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.914274981243082
# faction added : [-0.00080301 -0.00186672]
# Saturation ratio: [9.04815617e-01 9.07544125e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9137336486626411
# faction added : [-0.00080176 -0.00189769]
# Saturation ratio: [9.04090172e-01 9.05821889e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9131828429548511
# faction added : [-0.00080048 -0.00192752]
# Saturation ratio: [9.03366466e-01 9.04075898e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9126339751922771
# faction added : [-0.00079917 -0.00195626]
# Saturation ratio: [9.02644522e-01 9.02307287e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9120839091941455
# faction added : [-0.00079784 -0.00198396]
# Saturation ratio: [9.01924360e-01 9.00517147e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.911536197371832
# faction added : [-0.00079648 -0.00201064]
# Saturation ratio: [9.01205999e-01 8.98706530e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.910989326487189
# faction added : [-0.00079509 -0.00203635]
# Saturation ratio: [9.00489456e-01 8.96876445e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9104421956612462
# faction added : [-0.00079369 -0.00206113]
# Saturation ratio: [8.99774745e-01 8.95027866e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9098956856311038
# faction added : [-0.00079227 -0.002085  ]
# Saturation ratio: [8.99061882e-01 8.93161729e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9093501896061251
# faction added : [-0.00079083 -0.00210801]
# Saturation ratio: [8.98350878e-01 8.91278936e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9088055253954682
# faction added : [-0.00078937 -0.00213017]
# Saturation ratio: [8.97641744e-01 8.89380357e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9082607006636597
# faction added : [-0.0007879  -0.00215153]
# Saturation ratio: [8.96934490e-01 8.87466829e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9077179591601596
# faction added : [-0.00078642 -0.0021721 ]
# Saturation ratio: [8.96229124e-01 8.85539158e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.907175283801695
# faction added : [-0.00078492 -0.00219192]
# Saturation ratio: [8.95525654e-01 8.83598124e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9066336240998154
# faction added : [-0.00078342 -0.00221101]
# Saturation ratio: [8.94824085e-01 8.81644476e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.906092581519072
# faction added : [-0.0007819 -0.0022294]
# Saturation ratio: [8.94124422e-01 8.79678937e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.905552523769337
# faction added : [-0.00078037 -0.00224711]
# Saturation ratio: [8.93426670e-01 8.77702205e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9050133613678911
# faction added : [-0.00077884 -0.00226415]
# Saturation ratio: [8.92730832e-01 8.75714952e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9044751490807414
# faction added : [-0.0007773  -0.00228056]
# Saturation ratio: [8.92036908e-01 8.73717828e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.903937758068176
# faction added : [-0.00077576 -0.00229636]
# Saturation ratio: [8.91344902e-01 8.71711459e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9034011579938522
# faction added : [-0.00077421 -0.00231156]
# Saturation ratio: [8.90654812e-01 8.69696449e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.902865743748226
# faction added : [-0.00077266 -0.00232618]
# Saturation ratio: [8.89966639e-01 8.67673379e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9023311442854842
# faction added : [-0.0007711  -0.00234024]
# Saturation ratio: [8.89280382e-01 8.65642814e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9017975016024201
# faction added : [-0.00076955 -0.00235376]
# Saturation ratio: [8.88596039e-01 8.63605296e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9012648238448808
# faction added : [-0.00076799 -0.00236676]
# Saturation ratio: [8.87913607e-01 8.61561347e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9007330999715718
# faction added : [-0.00076643 -0.00237925]
# Saturation ratio: [8.87233084e-01 8.59511475e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.9002023985703757
# faction added : [-0.00076487 -0.00239125]
# Saturation ratio: [8.86554466e-01 8.57456165e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8996726698491296
# faction added : [-0.00076331 -0.00240278]
# Saturation ratio: [8.85877749e-01 8.55395890e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8991437449430173
# faction added : [-0.00076175 -0.00241384]
# Saturation ratio: [8.85202928e-01 8.53331103e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8986162019587424
# faction added : [-0.0007602  -0.00242445]
# Saturation ratio: [8.84529999e-01 8.51262242e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8980894543862581
# faction added : [-0.00075864 -0.00243463]
# Saturation ratio: [8.83858956e-01 8.49189731e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8975637950272398
# faction added : [-0.00075709 -0.00244439]
# Saturation ratio: [8.83189792e-01 8.47113977e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8970390930301955
# faction added : [-0.00075554 -0.00245375]
# Saturation ratio: [8.82522503e-01 8.45035374e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.896515462084348
# faction added : [-0.000754  -0.0024627]
# Saturation ratio: [8.81857082e-01 8.42954302e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8959928462248556
# faction added : [-0.00075246 -0.00247128]
# Saturation ratio: [8.81193520e-01 8.40871127e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8954711846722914
# faction added : [-0.00075092 -0.00247948]
# Saturation ratio: [8.80531813e-01 8.38786203e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8949507048193781
# faction added : [-0.00074939 -0.00248732]
# Gas mixture at 298.15 K and 101325.0 Pa consisting of ["['H2O', 'NH4HSO4']"]
# [0]: Particle Representation:
# 	Strategy: SpeciatedMassMovingBin
# 	Activity: ActivityKappaParameter
# 	Surface: SurfaceStrategyVolume
# 	Mass Concentration: 1.626e-03 [kg/m^3]
# 	Number Concentration: 1.000e+10 [#/m^3]
# Saturation ratio: [8.79871952e-01 8.36699871e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8944311762993173
# faction added : [-0.00074786 -0.00249482]
# Saturation ratio: [8.79213929e-01 8.34612459e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8939127233176825
# faction added : [-0.00074634 -0.00250197]
# Saturation ratio: [8.78557738e-01 8.32524284e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8933953039568082
# faction added : [-0.00074482 -0.00250879]
# Saturation ratio: [8.77903369e-01 8.30435652e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8928789146057887
# faction added : [-0.00074331 -0.0025153 ]
# Saturation ratio: [8.77250815e-01 8.28346858e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8923635917244919
# faction added : [-0.0007418  -0.00252149]
# Saturation ratio: [8.76600068e-01 8.26258186e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8918493075454771
# faction added : [-0.0007403  -0.00252739]
# Saturation ratio: [8.75951119e-01 8.24169909e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8913360713403238
# faction added : [-0.00073881 -0.00253299]
# Saturation ratio: [8.75303960e-01 8.22082291e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8908238847162612
# faction added : [-0.00073732 -0.00253832]
# Saturation ratio: [8.74658581e-01 8.19995586e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8903127466536336
# faction added : [-0.00073584 -0.00254336]
# Saturation ratio: [8.74014976e-01 8.17910039e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8898026574418336
# faction added : [-0.00073436 -0.00254815]
# Saturation ratio: [8.73373134e-01 8.15825885e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8892936190866824
# faction added : [-0.00073289 -0.00255267]
# Saturation ratio: [8.72733046e-01 8.13743351e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8887856190764192
# faction added : [-0.00073143 -0.00255694]
# Saturation ratio: [8.72094706e-01 8.11662655e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8882786790173222
# faction added : [-0.00072997 -0.00256097]
# Saturation ratio: [8.71458102e-01 8.09584009e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8877727826437772
# faction added : [-0.00072852 -0.00256477]
# Saturation ratio: [8.70823227e-01 8.07507613e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8872679073628635
# faction added : [-0.00072708 -0.00256834]
# Saturation ratio: [8.70190072e-01 8.05433662e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.886764045457738
# faction added : [-0.00072564 -0.00257168]
# Saturation ratio: [8.69558628e-01 8.03362343e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8862613545596782
# faction added : [-0.00072421 -0.00257481]
# Saturation ratio: [8.68928886e-01 8.01293836e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8857596403658009
# faction added : [-0.00072278 -0.00257773]
# Saturation ratio: [8.68300838e-01 7.99228313e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.
-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.857908200128708
# faction added : [-0.00064669 -0.00253797]
# Saturation ratio: [8.33987452e-01 6.86142152e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8574588910653913
# faction added : [-0.00064546 -0.00253542]
# Saturation ratio: [8.33449143e-01 6.84402496e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8570203110777322
# faction added : [-0.00064424 -0.00253284]
# Saturation ratio: [8.32912206e-01 6.82669017e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8565795695507993
# faction added : [-0.00064301 -0.00253023]
# Saturation ratio: [8.32376638e-01 6.80941707e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8561375205203856
# faction added : [-0.00064178 -0.0025276 ]
# Saturation ratio: [8.31842437e-01 6.79220561e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8556977232973836
# faction added : [-0.00064055 -0.00252494]
# Saturation ratio: [8.31309603e-01 6.77505569e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8552569711583665
# faction added : [-0.00063932 -0.00252226]
# Saturation ratio: [8.30778132e-01 6.75796724e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8548177927554538
# faction added : [-0.00063809 -0.00251955]
# Saturation ratio: [8.30248022e-01 6.74094018e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8543814577091751
# faction added : [-0.00063686 -0.00251683]
# Saturation ratio: [8.29719273e-01 6.72397439e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.853941466840987
# faction added : [-0.00063563 -0.00251408]
# Saturation ratio: [8.29191882e-01 6.70706979e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8535081349863349
# faction added : [-0.00063439 -0.00251131]
# Saturation ratio: [8.28665847e-01 6.69022626e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8530721052624715
# faction added : [-0.00063316 -0.00250852]
# Saturation ratio: [8.28141166e-01 6.67344370e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8526331140922829
# faction added : [-0.00063193 -0.00250571]
# Saturation ratio: [8.27617839e-01 6.65672198e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8522043846820262
# faction added : [-0.0006307  -0.00250288]
# Saturation ratio: [8.27095863e-01 6.64006099e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8517721399905586
# faction added : [-0.00062946 -0.00250004]
# Saturation ratio: [8.26575237e-01 6.62346060e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8513396118198173
# faction added : [-0.00062823 -0.00249717]
# Saturation ratio: [8.26055960e-01 6.60692068e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8509095307616554
# faction added : [-0.00062699 -0.00249429]
# Saturation ratio: [8.25538029e-01 6.59044110e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8504760449540628
# faction added : [-0.00062576 -0.00249139]
# Saturation ratio: [8.25021443e-01 6.57402173e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8500392061756903
# faction added : [-0.00062452 -0.00248848]
# Saturation ratio: [8.24506201e-01 6.55766241e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.849602888459582
# faction added : [-0.00062328 -0.00248555]
# Saturation ratio: [8.23992301e-01 6.54136300e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8491858912894853
# faction added : [-0.00062204 -0.00248261]
# Saturation ratio: [8.23479742e-01 6.52512337e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8487655593460729
# faction added : [-0.0006208  -0.00247965]
# Saturation ratio: [8.22968523e-01 6.50894336e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8483419407693668
# faction added : [-0.00061956 -0.00247668]
# Saturation ratio: [8.22458642e-01 6.49282281e-06]
# solute volume fractions: (1000, 1)
# mean water activity: 0.8479163880103705
# faction added : [-0.00061832 -0.00247369]
# Gas mixture at 298.15 K and 101325.0 Pa consisting of ["['H2O', 'NH4HSO4']"]
# [0]: Particle Representation:
# 	Strategy: SpeciatedMassMovingBin
# 	Activity: ActivityKappaParameter
# 	Surface: SurfaceStrategyVolume
# 	Mass Concentration: 2.960e-03 [kg/m^3]
# 	Number Concentration: 1.000e+10 [#/m^3]

# %% [markdown]
# ## Small Particles Grow Faster
#
# We can see from the previous example that the smaller particles grow faster than the larger particles. This is because the smaller particles have a higher surface area to volume ratio, which means they can take up more water.
#
# However, that

# %% [markdown]
# ## Summary
#
# We built out the condensation process, and the equations that define the process. We also defined the inputs and outputs of the process. Next we will build out coagulation and nucleation processes, to complete the aerosol dynamics framework.
